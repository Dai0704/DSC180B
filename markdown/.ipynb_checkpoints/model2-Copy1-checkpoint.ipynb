# %%
import pandas as pd
import numpy as np
import sklearn
import seaborn as sns
from matplotlib import pyplot as plt
from matplotlib import rcParams
import os

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import make_classification
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import accuracy_score
#from xgboost import XGBClassifier

# %%
df = pd.read_csv('../data/cardio_train.csv',sep=";")

# %%
# age: 1 - women, 2 - men
#cholesterol: (1: normal, 2: above normal, 3: well above normal)
#gluc: (1: normal, 2: above normal, 3: well above normal)
df.head(5)
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %%
df.isnull().values.any()
# Out:
# False

# %%
df['age'] = (df['age'] / 365).round().astype('int')

# %%
bins= [30,35,40,45,50,55,60,65]
labels = ["30-35","35-40","40-45","45-50","50-55","55-60","60-65"]
df['AgeGroup'] = pd.cut(df['age'], bins=bins, labels=labels, right=False)

# %%
df.head(5)
# Out:
#    id  age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0   50       2     168    62.0    110     80            1     1      0
# 1   1   55       1     156    85.0    140     90            3     1      0
# 2   2   52       1     165    64.0    130     70            3     1      0
# 3   3   48       2     169    82.0    150    100            1     1      0
# 4   4   48       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio AgeGroup
# 0     0       1       0    50-55
# 1     0       1       1    55-60
# 2     0       0       1    50-55
# 3     0       1       1    45-50
# 4     0       0       0    45-50

# %%
df.describe()
# Out:
#                  id           age        gender        height        weight  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean   49972.419900     53.338686      1.349571    164.359229     74.205690
# std    28851.302323      6.765294      0.476838      8.210126     14.395757
# min        0.000000     30.000000      1.000000     55.000000     10.000000
# 25%    25006.750000     48.000000      1.000000    159.000000     65.000000
# 50%    50001.500000     54.000000      1.000000    165.000000     72.000000
# 75%    74889.250000     58.000000      2.000000    170.000000     82.000000
# max    99999.000000     65.000000      2.000000    250.000000    200.000000
#
#               ap_hi         ap_lo   cholesterol          gluc         smoke  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean     128.817286     96.630414      1.366871      1.226457      0.088129
# std      154.011419    188.472530      0.680250      0.572270      0.283484
# min     -150.000000    -70.000000      1.000000      1.000000      0.000000
# 25%      120.000000     80.000000      1.000000      1.000000      0.000000
# 50%      120.000000     80.000000      1.000000      1.000000      0.000000
# 75%      140.000000     90.000000      2.000000      1.000000      0.000000
# max    16020.000000  11000.000000      3.000000      3.000000      1.000000
#
#                alco        active        cardio
# count  70000.000000  70000.000000  70000.000000
# mean       0.053771      0.803729      0.499700
# std        0.225568      0.397179      0.500003
# min        0.000000      0.000000      0.000000
# 25%        0.000000      1.000000      0.000000
# 50%        0.000000      1.000000      0.000000
# 75%        0.000000      1.000000      1.000000
# max        1.000000      1.000000      1.000000

# %%
sns.countplot(x='AgeGroup', hue='cardio', data = df)

# %%
sns.boxplot(x='cardio',y='age',data=df)

# %%
cardio = df[df.cardio == 1]
noncardio = df[df.cardio == 0]

# %%
rcParams['figure.figsize'] = 11, 8

# %%
fig, ax =plt.subplots(1,2)
cardio_cate = cardio.loc[:,['cholesterol','gluc', 'smoke', 'alco', 'active']]
sns.countplot(x="variable", hue="value",data= pd.melt(cardio_cate),ax=ax[0])
noncardio_cate = noncardio.loc[:,['cholesterol','gluc', 'smoke', 'alco', 'active']]
sns.countplot(x="variable", hue="value",data= pd.melt(noncardio_cate),ax=ax[1])

# %%
sns.countplot(x='gender', hue='cardio', data = df)

# %%
line_x1 = np.linspace(50, 250, 1000)
line_y1 = 11*((line_x1/100)**3)
line_x2 = np.linspace(50, 250, 1000)
line_y2 = 15*((line_x1/100)**3)

sns.scatterplot(x='height',y='weight', hue='gender', data = df)
plt.plot(line_x1, line_y1, color='r')
plt.plot(line_x2, line_y2, color='r')
plt.show()

# %%
line_x1 = np.linspace(50, 250, 1000)
line_y1 = 11*((line_x1/100)**3)
line_x2 = np.linspace(50, 250, 1000)
line_y2 = 15*((line_x1/100)**3)

sns.scatterplot(x='height',y='weight', hue='cardio', data = df)
plt.plot(line_x1, line_y1, color='r')
plt.plot(line_x2, line_y2, color='r')
plt.show()

# %%
df['ponderIndex'] = df['weight']/(df['height']/100)**3

# %%
bins= [0,3,7,11,15,19,23,27,31,35,39,44]
labels = ["0-3","3-7","7-11","11-15","15-19","19-23","23-27","27-31","31-35","35-39","39-44"]
df['PIGroup'] = pd.cut(df['ponderIndex'], bins=bins, labels=labels, right=False)

# %%
sns.countplot(x='PIGroup', hue='cardio', data = df)

# %%
df['ponderIndex'].describe()
# Out:
# count    69916.000000
# mean        16.776811
# std          3.489239
# min          1.950440
# 25%         14.404297
# 50%         15.972367
# 75%         18.554687
# max         44.356049
# Name: ponderIndex, dtype: float64

# %%
df = df.drop(df[df.ponderIndex > 45].index)

# %%
#try empirical null
plt.hist(df['height'],bins=50)
# Out:
# (array([2.0000e+00, 2.0000e+00, 4.0000e+00, 8.0000e+00, 3.0000e+00,
#         3.0000e+00, 2.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00,
#         2.0000e+00, 5.0000e+00, 4.0000e+00, 3.0000e+00, 1.0000e+01,
#         2.0000e+00, 3.5000e+01, 5.0000e+00, 1.0000e+00, 1.6000e+01,
#         1.8000e+01, 7.4000e+01, 1.6700e+02, 8.2900e+02, 3.1670e+03,
#         7.0390e+03, 1.2143e+04, 1.0881e+04, 1.4769e+04, 8.7820e+03,
#         6.4590e+03, 3.2460e+03, 1.5570e+03, 5.7300e+02, 1.3500e+02,
#         2.6000e+01, 2.4000e+01, 1.0000e+00, 1.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00]),
#  array([ 55. ,  58.9,  62.8,  66.7,  70.6,  74.5,  78.4,  82.3,  86.2,
#          90.1,  94. ,  97.9, 101.8, 105.7, 109.6, 113.5, 117.4, 121.3,
#         125.2, 129.1, 133. , 136.9, 140.8, 144.7, 148.6, 152.5, 156.4,
#         160.3, 164.2, 168.1, 172. , 175.9, 179.8, 183.7, 187.6, 191.5,
#         195.4, 199.3, 203.2, 207.1, 211. , 214.9, 218.8, 222.7, 226.6,
#         230.5, 234.4, 238.3, 242.2, 246.1, 250. ]),
#  <a list of 50 Patch objects>)

# %%
x1 = list(df[df['cardio'] == 0]['ponderIndex'])
x2 = list(df[df['cardio'] == 1]['ponderIndex'])

colors = ['#E69F00', '#56B4E9']
names = ['Non-Cardio', 'Cardio']

plt.hist([x1, x2], bins = 10, normed=True,
         color = colors, label=names)

plt.legend()
plt.xlabel('PonderIndex')
plt.ylabel('Normalized PI')
plt.title('Side-by-Side Histogram')
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
# Text(0.5, 1.0, 'Side-by-Side Histogram')

# %%
df.hist()
plt.show()

# %%
corr = df.corr()
f, ax = plt.subplots()
sns.heatmap(corr, annot=True, ax=ax)

# %%
cardio_corr = df.corr()['cardio'].drop('cardio').sort_values(ascending=False).abs()
cardio_corr
# Out:
# age            0.237749
# cholesterol    0.221147
# weight         0.181660
# gluc           0.089307
# ap_lo          0.065719
# ap_hi          0.054475
# gender         0.008109
# id             0.003799
# alco           0.007330
# height         0.010821
# smoke          0.015486
# active         0.035653
# Name: cardio, dtype: float64

# %%
##logistic regression model

# %%
threshold = [0.002, 0.005, 0.01, 0.05, 0.1, 0.2]

# %%
for i in threshold:
    print(list(cardio_corr[cardio_corr > i].index))
# Out:
# ['age', 'cholesterol', 'weight', 'gluc', 'ap_lo', 'ap_hi', 'gender', 'id', 'alco', 'height', 'smoke', 'active']
# ['age', 'cholesterol', 'weight', 'gluc', 'ap_lo', 'ap_hi', 'gender', 'alco', 'height', 'smoke', 'active']
# ['age', 'cholesterol', 'weight', 'gluc', 'ap_lo', 'ap_hi', 'height', 'smoke', 'active']
# ['age', 'cholesterol', 'weight', 'gluc', 'ap_lo', 'ap_hi']
# ['age', 'cholesterol', 'weight']
# ['age', 'cholesterol']

# %%
model = LogisticRegression()

# %%
X = df.drop(['cardio'], axis=1)
y = df['cardio']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# %%
FPR_lst = []
TPR_lst = []
FDR_lst = []

for i in threshold:
    features = cardio_corr[cardio_corr > i].index
    model.fit(X_train[features],y_train)
    prediction = model.predict(X_test[features])
    
    TP_ = np.logical_and(prediction, y_test)
    FP_ = np.logical_and(prediction, np.logical_not(y_test))
    TN_ = np.logical_and(np.logical_not(prediction), np.logical_not(y_test))
    FN_ = np.logical_and(np.logical_not(prediction), y_test)
    
    TP = sum(TP_)
    FP = sum(FP_)
    TN = sum(TN_)
    FN = sum(FN_)
    
    FPR = FP/(FP+TN)
    FPR_lst.append(FPR)
    
    TPR = TP/(TP+FN)
    TPR_lst.append(TPR)

    FDR = FP/(FP+TP)
    FDR_lst.append(FDR)

    print(accuracy_score(prediction, y_test))
# Out:
# /Users/StefanChen/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# 0.7097619047619048
# /Users/StefanChen/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# 0.7191428571428572
# /Users/StefanChen/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# 0.719047619047619
# /Users/StefanChen/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# 0.7173333333333334
# 0.6373809523809524
# /Users/StefanChen/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/StefanChen/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# 0.6217142857142857

# %%
FPR_lst, TPR_lst
# Out:
# ([0.24420401854714066,
#   0.22720247295208656,
#   0.22720247295208656,
#   0.22787867078825347,
#   0.32351236476043277,
#   0.3422527047913447],
#  [0.665007513148009,
#   0.6669797145003756,
#   0.6667918858001503,
#   0.6640683696468821,
#   0.5993613824192336,
#   0.5866829451540195])

# %%
# line 1 points
x1 = threshold
y1 = FPR_lst
# plotting the line 1 points 
plt.plot(x1, y1, label = "False Positive Rate")


# line 2 points
x2 = threshold
y2 = TPR_lst
# plotting the line 2 points 
plt.plot(x2, y2, label = "True Positive Rate")

# line 3 points
x3 = threshold
y3 = FDR_lst
# plotting the line 2 points 
plt.plot(x3, y3, label = "False Discovery Rate")

plt.xlabel('Threshold')
# Set the y axis label of the current axis.
plt.ylabel('Rate')
# Set a title of the current axes.
plt.title('Rates as function of Threshold')
# show a legend on the plot
plt.legend()
# Display a figure.
plt.show()
